# %% [markdown]
# # Detecção de Objetos em Python com YOLOv8
# ### Computação Visual, 07G
# ### Integrantes: Bruno Antico Galin (10417318), Ismael de Sousa Silva (10410870), Lucas Kenzo Kawamoto (10396359), Vitor Alves Pereira (10410862).

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
modelo = YOLO('yolov8n.pt')

# %%
modelo.train(data='objetos/data.yaml',epochs=20,imgsz=640)
# Out:
# Ultralytics 8.4.41  Python-3.14.4 torch-2.11.0+cpu CPU (AMD Ryzen 5 3500U with Radeon Vega Mobile Gfx)
# ...

# %%
img = cv2.imread('objetos_v2/imagens/treino/airfryer1.jpg')
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12482/1584253595.py in <cell line: 0>()
#       1 img = cv2.imread('objetos_v2/imagens/treino/airfryer1.jpg')
# ----> 2 plt.imshow(img)
#       3 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3590     **kwargs,
#    3591 ) -> AxesImage:
# -> 3592     __ret = gca().imshow(
#    3593         X,
#    3594         cmap=cmap,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
# ...
